# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten

# %%
# Load the datasets using Pandas
fashion_train_df = pd.read_csv('fashion-mnist_train.csv')
fashion_test_df = pd.read_csv('fashion-mnist_test.csv')

# %%
# Extract features and labels from the datasets
# refers to retrieving the target variable or the class labels from the dataset.
train_labels = fashion_train_df['label'].values
test_labels = fashion_test_df['label'].values
#xtracting features refers to isolating or retrieving the input variables from the dataset that are used to make predictions or classifications.

# %%
#This drops the 'label' column from the DataFrame, leaving only the pixel values of the images.
train_images = fashion_train_df.drop('label', axis=1).values.reshape(-1, 28, 28)
test_images = fashion_test_df.drop('label', axis=1).values.reshape(-1, 28, 28)

# %%
# Print shape of training and testing datasets after reshape
print("Training Images Shape (After Reshape):", train_images.shape)
print("Testing Images Shape (After Reshape):", test_images.shape)
# Out:
# Training Images Shape (After Reshape): (60000, 28, 28)
# Testing Images Shape (After Reshape): (10000, 28, 28)

# %%
# Preprocess the data
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
# Define class names
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# Display an image from the dataset
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
# Build the neural network model
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])
# Out:
# C:\Users\Akshay Budhabal\anaconda3\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - accuracy: 0.7849 - loss: 0.6243
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8599 - loss: 0.3880
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8729 - loss: 0.3448
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8834 - loss: 0.3170
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8896 - loss: 0.3010
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8946 - loss: 0.2862
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8995 - loss: 0.2734
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9070 - loss: 0.2556
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9081 - loss: 0.2496
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9121 - loss: 0.2384

# %%
# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print('Test accuracy:', test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8849 - loss: 0.3126
# Test accuracy: 0.8895999789237976

# %%
# Make predictions
predictions = model.predict(test_images)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(test_images[i], cmap=plt.cm.binary)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    predicted_label = np.argmax(predictions[i])
    plt.xlabel(f"{class_names[predicted_label]} ({class_names[test_labels[i]]})", color='blue' if predicted_label == test_labels[i] else 'red')
plt.show()

# %%
# Plot the first 25 test images and their predicted labels
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_images[i], cmap=plt.cm.binary)
    predicted_label = np.argmax(predictions[i])
    true_label = test_labels[i]
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'
    plt.xlabel("{} ({})".format(class_names[predicted_label], class_names[true_label]), color=color)
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# Make predictions on the test set
predicted_labels = np.argmax(model.predict(test_images), axis=-1)

# Calculate accuracy
accuracy = accuracy_score(test_labels, predicted_labels)

# Calculate precision
precision = precision_score(test_labels, predicted_labels, average='weighted')

# Calculate recall
recall = recall_score(test_labels, predicted_labels, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# C:\Users\Akshay Budhabal\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14912\1104752930.py in <module>
#       2
#       3 # Make predictions on the test set
# ----> 4 predicted_labels = np.argmax(model.predict(test_images), axis=-1)
#       5
#       6 # Calculate accuracy
#
# NameError: name 'np' is not defined
